# %% [markdown]
# # Pet Finder

# %%
import pandas as pd
import numpy as np
import os
import shutil
import pathlib
from matplotlib import pyplot as plt
import PIL

import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

from keras.applications.resnet import ResNet50, decode_predictions
from keras_preprocessing import image

# %% [markdown]
# Our project is based on a Kaggle competition called PetFinder. We chose this particular project as it has a lot of images and other relevant information related to these pictures. Thus, the data from this competition can be used for different types of applications. Our project tries to achieve three types of classification using Convolutional Neural Network: a dog/cat classifier, a dog breed classifier and a cat breed classifier using methods from the tensorflow library.

# %% [markdown]
# #### Data manipulation

# %% [markdown]
# Our data is stored in a csv file. We will load that file and do some cleanups, such as removing unnecessary columns and unsuitable entries. These entries are those that have more animals in a single entry and those that do not have any photos.

# %%
def create_directory(path):
    if os.path.exists(path) and os.path.isdir(path):
        shutil.rmtree(path)
    os.mkdir(path)

# %%
df = pd.read_csv('./train.csv')
df = df.query('Quantity == 1 & PhotoAmt > 0')

# %% [markdown]
# We chose to discard the other columns as they include irelevant data such as age, whether they were adopted, etc. We only need the PetID and Breed1 columns to be able to link pictures with species and breeds later on in the project.

# %%
df = df[['PetID', 'Breed1']]
df.rename(columns={'PetID': 'PetID', 'Breed1': 'Breed'}, inplace=True)
df.shape
# Out:
# (11330, 2)

# %% [markdown]
# With our data separated, let's take a look at the breeds and how they vary across cats and dogs.

# %%
breed_df = pd.read_csv('./BreedLabels.csv')
breed_df=pd.DataFrame(breed_df)
breed_df.shape
# Out:
# (307, 3)

# %% [markdown]
# From the Breed Labels csv file, we know that we have 307 different breeds.
# On the next step, let's take a look at how many of them are dog breeds and how many are cat breeds.

# %% [markdown]
# Number of dog breeds:

# %%
dog_breeds = breed_df.query(' Type == 1 ')
dog_breeds.shape[0]
# Out:
# 241

# %% [markdown]
# Number of cat breeds:

# %%
cat_breeds = breed_df.query(' Type == 2 ')
cat_breeds.shape[0]
# Out:
# 66

# %%
df.dtypes
# Out:
# PetID    object
# Breed     int64
# dtype: object

# %%
breed_df = breed_df.astype(str)
breed_df.dtypes
# Out:
# BreedID      object
# Type         object
# BreedName    object
# dtype: object

# %%
df['Breed']=df['Breed'].astype(str)

# %%
df.head()
# Out:
#        PetID Breed
# 0  86e1089a3   299
# 1  6296e909a   265
# 2  3422e4906   307
# 3  5842f1ff5   307
# 4  850a43f90   307

# %% [markdown]
# In the following code we iterate through the dataframe and for each entry check what species the animal is and update the Species column for that row. Also, because our original dataframe used codes to identify animals to their breeds through an additional csv file, we chose to update the Breed column for easier manipulation of images.

# %%
for index, row in df.iterrows():
    if row['Breed'] in breed_df['BreedID'].values:
        #if Type from breed_df is '1' Species is dog else cat
        if breed_df[breed_df['BreedID'] == row['Breed']]['Type'].values[0] == '1':
            df.at[index, 'Species'] = 'dog'
        else:
            df.at[index, 'Species'] = 'cat'
        df.loc[index, 'Breed'] = breed_df[breed_df['BreedID'] == row['Breed']]['BreedName'].values[0]

# %%
df.head()
# Out:
#        PetID                 Breed Species
# 0  86e1089a3                 Tabby     cat
# 1  6296e909a  Domestic Medium Hair     cat
# 2  3422e4906           Mixed Breed     dog
# 3  5842f1ff5           Mixed Breed     dog
# 4  850a43f90           Mixed Breed     dog

# %%
df.query('Species == "dog" & Breed != "Mixed Breed"').shape[0]
# Out:
# 1915

# %% [markdown]
# With our data frame properly manipulated, we can now split the images in directories for cats and dogs.

# %% [markdown]
# train_images_path = './train_images'
# out_path = './train/'
#
# create_directory('./train/dogs')
# create_directory('./train/cats')
#
# for _, row in df.iterrows():
#     if not row['Species'] in ['dog', 'cat']:
#         continue
#
#     files = os.listdir(train_images_path)
#     pet_id_images = [ os.path.join(train_images_path, image) for image in files if os.path.isfile(os.path.join(train_images_path, image)) and row['PetID'] in image ]
#     for image in pet_id_images:
#         shutil.copy(image, os.path.join(out_path, row['Species'] + 's'))

# %% [markdown]
# We plotted the distribution of breeds in our dataset in two ways for easy understanding of the size and quality of our data.

# %%
df.groupby(['Species', 'Breed']).count()['PetID'].unstack().plot(kind='bar', stacked=True, figsize=(10, 8))
# Out:
# <AxesSubplot:xlabel='Species'>

# %%
#plot the distribution of the number of entries per breed
df.groupby(['Breed']).count()['PetID'].sort_values(ascending=False).plot(kind='bar', figsize=(30, 8))
# Out:
# <AxesSubplot:xlabel='Breed'>

# %%
pd.DataFrame(df.groupby(['Breed']).count()['PetID'].sort_values(ascending=False)).query('PetID > 100')
# Out:
#                       PetID
# Breed
# Mixed Breed            4564
# Domestic Short Hair    2562
# Domestic Medium Hair    855
# Tabby                   240
# Domestic Long Hair      221
# Siamese                 198
# Persian                 173
# Shih Tzu                168
# Labrador Retriever      167
# Poodle                  152
# Terrier                 141
# Golden Retriever        126

# %% [markdown]
# With our data ready, let's begin preparing our dataset.

# %% [markdown]
# We define some constants for our training model. After that we split the training and validation dataset into an 80-20 distribution. Thus, the final dataset will be 22.7k for training and 5.6k for validation.

# %%
batch_size = 32
img_height = 180
img_width = 180
data_dir = pathlib.Path('./train')

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 41710 files belonging to 2 classes.
# Using 33368 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 41710 files belonging to 2 classes.
# Using 8342 files for validation.

# %%
normalization_layer = layers.Rescaling(1./255)

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixel values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 0.9198986

# %% [markdown]
# This is the actual model creation. We rescale each layer to be the size we have defined before. The Conv2D argument is a 2D convolutional layer, used to create a convolution kernel that will be used to create tensor outputs. The activation function we chose to use is ReLU(Rectified Linear Unit), because it does not activate all the neurons at the same time thus resulting in a much lower computational time, especially in very big data applications. MaxPooling2D downsamples the input along the height and width dimensions by taking the maximum value over an input window that moves across the image in a shifting movement. The flatten operator is used to transform the resulting image into an array. Dense creates a layer with the neurons fully connected.

# %%
class_names = train_ds.class_names
num_classes = len(class_names)

model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# This is a summary of the number of trainable params after each of the operators has done its job. As we can see, at the end, our model ends up with almost 4 million trainable params.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 128)               3965056
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 3,988,898
# Trainable params: 3,988,898
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# This is where we train the model that we have previously defined. We use 10 epochs.

# %%
epochs=10
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 1043/1043 [==============================] - 308s 294ms/step - loss: 0.6418 - accuracy: 0.6405 - val_loss: 0.5826 - val_accuracy: 0.6918
# Epoch 2/10
# 1043/1043 [==============================] - 275s 264ms/step - loss: 0.5501 - accuracy: 0.7195 - val_loss: 0.5480 - val_accuracy: 0.7224
# Epoch 3/10
#  798/1043 [=====================>........] - ETA: 1:00 - loss: 0.4992 - accuracy: 0.7590
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Andrei\Desktop\University\Year 3 Semester 2\Intelligent Systems\Project_One\breed-detector\main.ipynb Cell 44' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Andrei/Desktop/University/Year%203%20Semester%202/Intelligent%20Systems/Project_One/breed-detector/main.ipynb#ch0000042?line=0'>1</a> epochs=10
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Andrei/Desktop/University/Year%203%20Semester%202/Intelligent%20Systems/Project_One/breed-detector/main.ipynb#ch0000042?line=1'>2</a> history = model.fit(
#       <a href='vscode-notebook-cell:/c%3A/Users/Andrei/Desktop/University/Year%203%20Semester%202/Intelligent%20Systems/Project_One/breed-detector/main.ipynb#ch0000042?line=2'>3</a>   train_ds,
#       <a href='vscode-notebook-cell:/c%3A/Users/Andrei/Desktop/University/Year%203%20Semester%202/Intelligent%20Systems/Project_One/breed-detector/main.ipynb#ch0000042?line=3'>4</a>   validation_data=val_ds,
#       <a href='vscode-notebook-cell:/c%3A/Users/Andrei/Desktop/University/Year%203%20Semester%202/Intelligent%20Systems/Project_One/breed-detector/main.ipynb#ch0000042?line=4'>5</a>   epochs=epochs
#       <a href='vscode-notebook-cell:/c%3A/Users/Andrei/Desktop/University/Year%203%20Semester%202/Intelligent%20Systems/Project_One/breed-detector/main.ipynb#ch0000042?line=5'>6</a> )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/keras/utils/traceback_utils.py?line=61'>62</a> filtered_tb = None
#      <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/keras/utils/traceback_utils.py?line=62'>63</a> try:
# ---> <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/keras/utils/traceback_utils.py?line=63'>64</a>   return fn(*args, **kwargs)
#      <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/keras/utils/traceback_utils.py?line=64'>65</a> except Exception as e:  # pylint: disable=broad-except
#      <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/keras/utils/traceback_utils.py?line=65'>66</a>   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\engine\training.py:1409, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/keras/engine/training.py?line=1401'>1402</a> with tf.profiler.experimental.Trace(
#    <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/keras/engine/training.py?line=1402'>1403</a>     'train',
#    <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/keras/engine/training.py?line=1403'>1404</a>     epoch_num=epoch,
#    <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/keras/engine/training.py?line=1404'>1405</a>     step_num=step,
#    <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/keras/engine/training.py?line=1405'>1406</a>     batch_size=batch_size,
#    <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/keras/engine/training.py?line=1406'>1407</a>     _r=1):
#    <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/keras/engine/training.py?line=1407'>1408</a>   callbacks.on_train_batch_begin(step)
# -> <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/keras/engine/training.py?line=1408'>1409</a>   tmp_logs = self.train_function(iterator)
#    <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/keras/engine/training.py?line=1409'>1410</a>   if data_handler.should_sync:
#    <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/keras/engine/training.py?line=1410'>1411</a>     context.async_wait()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/util/traceback_utils.py?line=147'>148</a> filtered_tb = None
#     <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/util/traceback_utils.py?line=148'>149</a> try:
# --> <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/util/traceback_utils.py?line=149'>150</a>   return fn(*args, **kwargs)
#     <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/util/traceback_utils.py?line=150'>151</a> except Exception as e:
#     <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/util/traceback_utils.py?line=151'>152</a>   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/def_function.py?line=911'>912</a> compiler = "xla" if self._jit_compile else "nonXla"
#     <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/def_function.py?line=913'>914</a> with OptionalXlaContext(self._jit_compile):
# --> <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/def_function.py?line=914'>915</a>   result = self._call(*args, **kwds)
#     <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/def_function.py?line=916'>917</a> new_tracing_count = self.experimental_get_tracing_count()
#     <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/def_function.py?line=917'>918</a> without_tracing = (tracing_count == new_tracing_count)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/def_function.py?line=943'>944</a>   self._lock.release()
#     <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/def_function.py?line=944'>945</a>   # In this case we have created variables on the first call, so we run the
#     <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/def_function.py?line=945'>946</a>   # defunned version which is guaranteed to never create variables.
# --> <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/def_function.py?line=946'>947</a>   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/def_function.py?line=947'>948</a> elif self._stateful_fn is not None:
#     <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/def_function.py?line=948'>949</a>   # Release the lock early so that multiple threads can perform the call
#     <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/def_function.py?line=949'>950</a>   # in parallel.
#     <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/def_function.py?line=950'>951</a>   self._lock.release()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow\python\eager\function.py:2453, in Function.__call__(self, *args, **kwargs)
#    <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/function.py?line=2449'>2450</a> with self._lock:
#    <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/function.py?line=2450'>2451</a>   (graph_function,
#    <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/function.py?line=2451'>2452</a>    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/function.py?line=2452'>2453</a> return graph_function._call_flat(
#    <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/function.py?line=2453'>2454</a>     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow\python\eager\function.py:1860, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/function.py?line=1855'>1856</a> possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/function.py?line=1856'>1857</a> if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/function.py?line=1857'>1858</a>     and executing_eagerly):
#    <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/function.py?line=1858'>1859</a>   # No tape is watching; skip to running the function.
# -> <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/function.py?line=1859'>1860</a>   return self._build_call_outputs(self._inference_function.call(
#    <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/function.py?line=1860'>1861</a>       ctx, args, cancellation_manager=cancellation_manager))
#    <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/function.py?line=1861'>1862</a> forward_backward = self._select_forward_and_backward_functions(
#    <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/function.py?line=1862'>1863</a>     args,
#    <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/function.py?line=1863'>1864</a>     possible_gradient_type,
#    <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/function.py?line=1864'>1865</a>     executing_eagerly)
#    <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/function.py?line=1865'>1866</a> forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow\python\eager\function.py:497, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/function.py?line=494'>495</a> with _InterpolateFunctionError(self):
#     <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/function.py?line=495'>496</a>   if cancellation_manager is None:
# --> <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/function.py?line=496'>497</a>     outputs = execute.execute(
#     <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/function.py?line=497'>498</a>         str(self.signature.name),
#     <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/function.py?line=498'>499</a>         num_outputs=self._num_outputs,
#     <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/function.py?line=499'>500</a>         inputs=args,
#     <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/function.py?line=500'>501</a>         attrs=attrs,
#     <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/function.py?line=501'>502</a>         ctx=ctx)
#     <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/function.py?line=502'>503</a>   else:
#     <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/function.py?line=503'>504</a>     outputs = execute.execute_with_cancellation(
#     <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/function.py?line=504'>505</a>         str(self.signature.name),
#     <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/function.py?line=505'>506</a>         num_outputs=self._num_outputs,
#    (...)
#     <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/function.py?line=508'>509</a>         ctx=ctx,
#     <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/function.py?line=509'>510</a>         cancellation_manager=cancellation_manager)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/execute.py?line=51'>52</a> try:
#      <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/execute.py?line=52'>53</a>   ctx.ensure_initialized()
# ---> <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/execute.py?line=53'>54</a>   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/execute.py?line=54'>55</a>                                       inputs, attrs, num_outputs)
#      <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/execute.py?line=55'>56</a> except core._NotOkStatusException as e:
#      <a href='file:///c%3A/Users/Andrei/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/tensorflow/python/eager/execute.py?line=56'>57</a>   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# We plot the Accuracy and Loss for both Training and Validation to show how our program's evolving throughout the training process.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)

# %%
model = Sequential([
  data_augmentation,
  layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 180, 180, 3)       0
#
#  rescaling_2 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_3 (Conv2D)           (None, 180, 180, 16)      448
#
#  max_pooling2d_3 (MaxPooling  (None, 90, 90, 16)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_4 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 22, 22, 64)        0
#
#  flatten_1 (Flatten)         (None, 30976)             0
#
#  dense_2 (Dense)             (None, 128)               3965056
#
#  dense_3 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 3,988,898
# Trainable params: 3,988,898
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 15
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/15
# 711/711 [==============================] - 478s 670ms/step - loss: 0.6431 - accuracy: 0.6304 - val_loss: 0.6526 - val_accuracy: 0.6264
# Epoch 2/15
# 711/711 [==============================] - 485s 682ms/step - loss: 0.5936 - accuracy: 0.6829 - val_loss: 0.5725 - val_accuracy: 0.6969
# Epoch 3/15
# 711/711 [==============================] - 491s 691ms/step - loss: 0.5697 - accuracy: 0.7019 - val_loss: 0.5592 - val_accuracy: 0.7080
# Epoch 4/15
# 711/711 [==============================] - 494s 695ms/step - loss: 0.5529 - accuracy: 0.7185 - val_loss: 0.5459 - val_accuracy: 0.7203
# Epoch 5/15
# 711/711 [==============================] - 497s 698ms/step - loss: 0.5378 - accuracy: 0.7301 - val_loss: 0.5406 - val_accuracy: 0.7244
# Epoch 6/15
# 711/711 [==============================] - 500s 703ms/step - loss: 0.5264 - accuracy: 0.7364 - val_loss: 0.5210 - val_accuracy: 0.7358
# Epoch 7/15
# 711/711 [==============================] - 509s 716ms/step - loss: 0.5104 - accuracy: 0.7491 - val_loss: 0.5180 - val_accuracy: 0.7411
# Epoch 8/15
# 711/711 [==============================] - 520s 731ms/step - loss: 0.4983 - accuracy: 0.7578 - val_loss: 0.5071 - val_accuracy: 0.7443
# Epoch 9/15
# 711/711 [==============================] - 530s 745ms/step - loss: 0.4850 - accuracy: 0.7669 - val_loss: 0.4924 - val_accuracy: 0.7564
# Epoch 10/15
# 711/711 [==============================] - 535s 752ms/step - loss: 0.4775 - accuracy: 0.7710 - val_loss: 0.4771 - val_accuracy: 0.7614
# Epoch 11/15
# 711/711 [==============================] - 538s 756ms/step - loss: 0.4674 - accuracy: 0.7757 - val_loss: 0.4795 - val_accuracy: 0.7647
# Epoch 12/15
# 711/711 [==============================] - 539s 759ms/step - loss: 0.4491 - accuracy: 0.7858 - val_loss: 0.4610 - val_accuracy: 0.7791
# Epoch 13/15
# 711/711 [==============================] - 540s 759ms/step - loss: 0.4481 - accuracy: 0.7880 - val_loss: 0.4618 - val_accuracy: 0.7805
# Epoch 14/15
# 711/711 [==============================] - 529s 744ms/step - loss: 0.4365 - accuracy: 0.7923 - val_loss: 0.4511 - val_accuracy: 0.7825
# Epoch 15/15
# 711/711 [==============================] - 534s 751ms/step - loss: 0.4262 - accuracy: 0.8006 - val_loss: 0.4383 - val_accuracy: 0.7900

# %% [markdown]
# This time we have chosen to do 15 epochs and as we can see from the plots down below, the accuracy and loss graphs don't jump as much.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# We tested this classifier with one picture of a dog, and our program, after being trained predicted that it is a dog with a confidence of almost 64%

# %%
test_images_path = './test_images'

data_dir = pathlib.Path('test_images/fe42c1ee7-3.jpg')
display_image = PIL.Image.open(str(data_dir))
display_image.show()

img = tf.keras.utils.load_img(
    data_dir, target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 2s 2s/step
# This image most likely belongs to dogs with a 63.71 percent confidence.
# (viewnior:26543): Gtk-WARNING **: 18:57:43.749: Unable to locate theme engine in module_path: "murrine",
#
# (viewnior:26543): Gtk-WARNING **: 18:57:43.749: Unable to locate theme engine in module_path: "murrine",
#
# (viewnior:26543): Gtk-WARNING **: 18:57:43.749: Unable to locate theme engine in module_path: "murrine",
#
# (viewnior:26543): Gtk-WARNING **: 18:57:43.758: Unable to locate theme engine in module_path: "murrine",
#
# (viewnior:26543): Gtk-WARNING **: 18:57:43.759: Unable to locate theme engine in module_path: "murrine",
#
# (viewnior:26543): Gtk-WARNING **: 18:57:43.759: Unable to locate theme engine in module_path: "murrine",
#
# (viewnior:26543): Gtk-WARNING **: 18:57:43.760: Unable to locate theme engine in module_path: "murrine",

# %% [markdown]
# Having already classified cats and dogs, a further interesting topic would be a breed classification among the species.

# %% [markdown]
# #### Breed classification

# %% [markdown]
# We already altered our dataframe to contain the breeds for us, so the data manipulation is no longer required. All we need to do now, is create our training directories.

# %% [markdown]
# First of all, we will create the top-level directories.

# %%
train_images_path = './train_images'
out_path = './train_breeds0'

create_directory(f'{out_path}')
create_directory(f'{out_path}/dogs')
create_directory(f'{out_path}/cats')

# %% [markdown]
# We split the cats and dogs images into two big directories and them every breed of cat and dog into subdirectories of their species' directory for our model to be able to access the class names that it will use when training the model furter ahead.

# %%
import string

dictionary = {
    "Mixed Breed": 0,
    "Domestic Short Hair":0,
    "Tabby":0,
    "Domestic Long Hair":0,
    "Siamese":0,
    "Persian":0, 
    "Shi Tzu":0, 
    "Labrador Retriever":0, 
    "Poodle":0,
    "Terrier":0, 
    "Golden Retriever":0
    
}
    
MAX_VALUE = 3

def remove_whitespaces(name):
    return name.translate({ord(c): None for c in string.whitespace})

for _, row in df.iterrows():
    breed = row['Breed']
   
    #if breed in Mixed Breed, Domestic Short Hair, Domestic Medium Hair, Tabby, Domestic Long Hair, Siamese, Persian, Shi Tzu, Labrador Retriever, Poodle, Terrier, Golden Retriever
    if breed in ['Mixed Breed', 'Domestic Short Hair', 'Tabby', 'Domestic Long Hair', 'Siamese', 'Persian', 'Shi Tzu', 'Labrador Retriever', 'Poodle', 'Terrier', 'Golden Retriever']:
        files = os.listdir(train_images_path)
        pet_id_images = [ os.path.join(train_images_path, image) for image in files if os.path.isfile(os.path.join(train_images_path, image)) and row['PetID'] in image ]
        for image in pet_id_images:
            if not row['Species'] in ['dog', 'cat']:
                continue
                
            dictionary[breed]+=1

                
            if (dictionary['Mixed Breed'] < MAX_VALUE):
                  dir_path = os.path.join(out_path, str(row['Species']) + 's', remove_whitespaces(str(row['Breed']).replace("/", "_")))
            
            else: 
                if (dictionary['Domestic Short Hair'] < MAX_VALUE):
                      dir_path = os.path.join(out_path, str(row['Species']) + 's', remove_whitespaces(str(row['Breed']).replace("/", "_")))
                else: 
                    if (dictionary['Tabby'] < MAX_VALUE):
                          dir_path = os.path.join(out_path, str(row['Species']) + 's', remove_whitespaces(str(row['Breed']).replace("/", "_")))
            
                    else: 
                        if (dictionary['Domestic Long Hair'] < MAX_VALUE):
                               dir_path = os.path.join(out_path, str(row['Species']) + 's', remove_whitespaces(str(row['Breed']).replace("/", "_")))
            
                        else: 
                            if (dictionary['Siamese'] < MAX_VALUE):
                                  dir_path = os.path.join(out_path, str(row['Species']) + 's', remove_whitespaces(str(row['Breed']).replace("/", "_")))
            
                            else: 
                                if (dictionary['Persian'] < MAX_VALUE):
                                  dir_path = os.path.join(out_path, str(row['Species']) + 's', remove_whitespaces(str(row['Breed']).replace("/", "_")))
            
                                else:
                                    if (dictionary['Labrador Retriever'] < MAX_VALUE):
                                      dir_path = os.path.join(out_path, str(row['Species']) + 's', remove_whitespaces(str(row['Breed']).replace("/", "_")))
            
                                    else: 
                                        if (dictionary['Poodle'] < MAX_VALUE):
                                          dir_path = os.path.join(out_path, str(row['Species']) + 's', remove_whitespaces(str(row['Breed']).replace("/", "_")))
                                        else:
                                            if (dictionary['Terrier'] < MAX_VALUE):
                                                  dir_path = os.path.join(out_path, str(row['Species']) + 's', remove_whitespaces(str(row['Breed']).replace("/", "_")))
                                            else:
                                                    if (dictionary['Golden Retriever'] < MAX_VALUE):
                                                          dir_path = os.path.join(out_path, str(row['Species']) + 's', remove_whitespaces(str(row['Breed']).replace("/", "_")))
                                                    else:
                                                        if (dictionary['Mixed Breed']==MAX_VALUE) and (dictionary['Domestic Short Hair']==MAX_VALUE) and (dictionary['Domestic Medium Hair']==MAX_VALUE) and (dictionary['Tabby']==MAX_VALUE) and (dictionary['Domestic Long Hair']==MAX_VALUE) and (dictionary['Siamese']==MAX_VALUE) and (dictionary['Persian']==MAX_VALUE) and (dictionary['Labrador Retriever']==MAX_VALUE) and (dictionary['Poodle']==MAX_VALUE) and (dictionary['Terrier']==MAX_VALUE) and (dictionary['Golden Retriever']==MAX_VALUE):
                                                            break
                
             
            if not (os.path.exists(dir_path) and os.path.isdir(dir_path)):
                create_directory(dir_path)
            shutil.copy(image, dir_path)

# %%
dog_data_dir = pathlib.Path('./train_breeds/dogs')

# %% [markdown]
# As with the cat/dog classifier we have to split the images into train and validation images. First we split the dog images, and the result is 18.1k images corresponding to 100 breeds have been chosen to be the training images, and the rest will be used to validate our models.

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  dog_data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 22720 files belonging to 107 classes.
# Using 18176 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  dog_data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 22720 files belonging to 107 classes.
# Using 4544 files for validation.

# %% [markdown]
# As with the previous classifier, we have to rescale our images to bring their values from between 0 and 255 to between 0 and 1.

# %%
normalization_layer = layers.Rescaling(1./255)

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixel values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 1.0

# %%
class_names = train_ds.class_names
num_classes = len(class_names)

# %%
class_names[:10:]
# Out:
# ['Akita',
#  'AmericanBulldog',
#  'AmericanStaffordshireTerrier',
#  'AmericanWaterSpaniel',
#  'AustralianKelpie',
#  'AustralianShepherd',
#  'AustralianTerrier',
#  'Basenji',
#  'BassetHound',
#  'Beagle']

# %% [markdown]
# We used the same training algorithm for the dog breed classifier as we have used for the dog/cat classifier

# %%
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)

# %%
model = Sequential([
  data_augmentation,
  layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# After defining our model we have 4 million trainable params for our neural network.

# %%
model.summary()
# Out:
# Model: "sequential_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_20 (Sequential)  (None, 180, 180, 3)       0
#
#  rescaling_17 (Rescaling)    (None, 180, 180, 3)       0
#
#  conv2d_33 (Conv2D)          (None, 180, 180, 16)      448
#
#  max_pooling2d_33 (MaxPoolin  (None, 90, 90, 16)       0
#  g2D)
#
#  conv2d_34 (Conv2D)          (None, 90, 90, 32)        4640
#
#  max_pooling2d_34 (MaxPoolin  (None, 45, 45, 32)       0
#  g2D)
#
#  conv2d_35 (Conv2D)          (None, 45, 45, 64)        18496
#
#  max_pooling2d_35 (MaxPoolin  (None, 22, 22, 64)       0
#  g2D)
#
#  dropout_5 (Dropout)         (None, 22, 22, 64)        0
#
#  flatten_11 (Flatten)        (None, 30976)             0
#
#  dense_22 (Dense)            (None, 128)               3965056
#
#  dense_23 (Dense)            (None, 107)               13803
#
# =================================================================
# Total params: 4,002,443
# Trainable params: 4,002,443
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 10
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 568/568 [==============================] - 425s 744ms/step - loss: 1.6822 - accuracy: 0.7099 - val_loss: 1.6117 - val_accuracy: 0.7163
# Epoch 2/10
# 568/568 [==============================] - 446s 786ms/step - loss: 1.6309 - accuracy: 0.7110 - val_loss: 1.5884 - val_accuracy: 0.7163
# Epoch 3/10
# 568/568 [==============================] - 453s 796ms/step - loss: 1.6164 - accuracy: 0.7111 - val_loss: 1.5685 - val_accuracy: 0.7163
# Epoch 4/10
# 568/568 [==============================] - 464s 816ms/step - loss: 1.6006 - accuracy: 0.7110 - val_loss: 1.5702 - val_accuracy: 0.7161
# Epoch 5/10
# 568/568 [==============================] - 453s 797ms/step - loss: 1.5953 - accuracy: 0.7112 - val_loss: 1.5587 - val_accuracy: 0.7163
# Epoch 6/10
# 568/568 [==============================] - 456s 802ms/step - loss: 1.5777 - accuracy: 0.7109 - val_loss: 1.5581 - val_accuracy: 0.7165
# Epoch 7/10
# 568/568 [==============================] - 459s 808ms/step - loss: 1.5661 - accuracy: 0.7109 - val_loss: 1.5501 - val_accuracy: 0.7161
# Epoch 8/10
# 568/568 [==============================] - 462s 814ms/step - loss: 1.5489 - accuracy: 0.7109 - val_loss: 1.5572 - val_accuracy: 0.7154
# Epoch 9/10
# 568/568 [==============================] - 468s 824ms/step - loss: 1.5330 - accuracy: 0.7107 - val_loss: 1.5406 - val_accuracy: 0.7157
# Epoch 10/10
# 568/568 [==============================] - 463s 815ms/step - loss: 1.5121 - accuracy: 0.7112 - val_loss: 1.5260 - val_accuracy: 0.7161

# %% [markdown]
# We plot both the Accuracy and Loss graphs for the two datasets, the Training and the Validation dataset.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# As we can see the plot don't look bad, only it is a little odd to see that the validation accuracy is a little higher than the one of the training. Altough their difference between their values is very. And on the loss side we can see that is is constantly decreasing

# %% [markdown]
# We tested this model to see how good it can predict based on a given photo of a Dalmatian.

# %%
src = cv2.imread('train_breeds/dogs/Dalmatian/0ab8ae91b-1.jpg')
plt.imshow(src)

# %% [markdown]
# The model was 77% confident that it saw a mixed Breed altough the image belong to Dalmatian folder. It is important to keep in mind that we decided to take only the first Breed1 from table. And from the data set it can be seen that is indeed a mixed breed between a Dalmatian and a Terrier.

# %%
test_images_path = './test_images'

data_dir = pathlib.Path('train_breeds/dogs/Dalmatian/0ab8ae91b-1.jpg')

display_image = PIL.Image.open(str(data_dir))
display_image.show()

img = tf.keras.utils.load_img(
    data_dir, target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])



print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 451ms/step
# This image most likely belongs to MixedBreed with a 77.21 percent confidence.
# (viewnior:40811): Gtk-WARNING **: 21:04:22.422: Unable to locate theme engine in module_path: "murrine",
#
# (viewnior:40811): Gtk-WARNING **: 21:04:22.422: Unable to locate theme engine in module_path: "murrine",
#
# (viewnior:40811): Gtk-WARNING **: 21:04:22.422: Unable to locate theme engine in module_path: "murrine",
#
# (viewnior:40811): Gtk-WARNING **: 21:04:22.424: Unable to locate theme engine in module_path: "murrine",
#
# (viewnior:40811): Gtk-WARNING **: 21:04:22.424: Unable to locate theme engine in module_path: "murrine",
#
# (viewnior:40811): Gtk-WARNING **: 21:04:22.424: Unable to locate theme engine in module_path: "murrine",
#
# (viewnior:40811): Gtk-WARNING **: 21:04:22.424: Unable to locate theme engine in module_path: "murrine",

# %% [markdown]
# We decided to try another approach and split our data. So we keept only the first 6 breeds of dogs. We choose the folder to have approximately same number of photos, around 415. And we tried testing on this little model. The data set cotained an inequal number of dogs of each breed so it was a real challenge for the model to be able to learn how to predict. So we tried to improve our data set in order to find a better model.

# %%
import cv2
import random

# %%
labels = os.listdir('./train_breeds0/dog')
print('Labels:', labels)
# Out:
# Labels: ['GoldenRetriever', 'LabradorRetriever', 'MixedBreed', 'Poodle', 'ShihTzu', 'Terrier']

# %%
train_dogs =[]
for i in range(5):
    img_names=os.listdir('./train_breeds0/dog/'+labels[i]+'/')
    for img in img_names:
          src= cv2.imread('./train_breeds0/dog/'+labels[i]+'/'+img)
          src= cv2.resize(src ,(100,100),interpolation=cv2.INTER_AREA)
          train_dogs.append((src,i))

# %% [markdown]
# We put the train data in a list that contained a tuple of the image and the label it belongs to. After that we shuffled it in order to create a good model

# %%
random.shuffle(train_dogs)

# %%
test_len = len(train_dogs)*0.2

# %% [markdown]
# For test we took 20% from our train data. We decided to take the first 20 items from the shuffled list

# %%
test_dogs = []
for i in range(int(test_len)):
    test_dogs.append(train_dogs[i])
    train_dogs.pop(i)

# %%
data_augmentation = keras.Sequential(
  [
   layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(0.2),
  layers.RandomContrast(0.2)
  ]
)

# %% [markdown]
# Because we knew that this could lead to overfitting we decided to do some data augmentation on out photos in order to prevent it

# %%
def prepare(ds):
  
  ds1 = map(lambda x: (data_augmentation(x[0], training=True), x[1]), ds)

  return list(ds1)

# %%
ds = prepare(train_dogs)
trainDogs=train_dogs + ds

# %% [markdown]
# We added the augmented data to the photos already found in train

# %% [markdown]
# We have created again the model

# %%
img_height = 100
img_width = 100
batch_size = 32

x_train = np.array([ i for i, j in trainDogs ])
y_train  = np.array([ j for i, j in trainDogs ])

model = Sequential([
  layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(10, activation='softmax'),
  
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
from keras import layers, models, callbacks

# %%
early_stop=callbacks.EarlyStopping(min_delta=0.01, patience=20, restore_best_weights=True)
history = model.fit(x_train, y_train, 
    validation_split=0.2,
    epochs=10,
    callbacks=[early_stop])
# Out:
# Epoch 1/10
# 84/84 [==============================] - 14s 159ms/step - loss: 1.6545 - accuracy: 0.2352 - val_loss: 1.6000 - val_accuracy: 0.2385
# Epoch 2/10
# 84/84 [==============================] - 13s 159ms/step - loss: 1.5515 - accuracy: 0.2997 - val_loss: 1.5897 - val_accuracy: 0.2489
# Epoch 3/10
# 84/84 [==============================] - 13s 155ms/step - loss: 1.4985 - accuracy: 0.3328 - val_loss: 1.5464 - val_accuracy: 0.3204
# Epoch 4/10
# 84/84 [==============================] - 13s 154ms/step - loss: 1.4114 - accuracy: 0.3966 - val_loss: 1.5678 - val_accuracy: 0.3159
# Epoch 5/10
# 84/84 [==============================] - 13s 153ms/step - loss: 1.3093 - accuracy: 0.4540 - val_loss: 1.5425 - val_accuracy: 0.3383
# Epoch 6/10
# 84/84 [==============================] - 13s 151ms/step - loss: 1.1851 - accuracy: 0.5244 - val_loss: 1.6250 - val_accuracy: 0.3025
# Epoch 7/10
# 84/84 [==============================] - 13s 151ms/step - loss: 1.0537 - accuracy: 0.5840 - val_loss: 1.6518 - val_accuracy: 0.3487
# Epoch 8/10
# 84/84 [==============================] - 13s 149ms/step - loss: 0.8911 - accuracy: 0.6482 - val_loss: 1.8938 - val_accuracy: 0.3145
# Epoch 9/10
# 84/84 [==============================] - 12s 148ms/step - loss: 0.7365 - accuracy: 0.7279 - val_loss: 2.1087 - val_accuracy: 0.2906
# Epoch 10/10
# 84/84 [==============================] - 13s 150ms/step - loss: 0.5989 - accuracy: 0.7794 - val_loss: 2.3376 - val_accuracy: 0.3189

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(10)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# As we could see the model behaved worse. So this wasn't the result that we expected, but we've found out that in our case, for our dataset the first model was a better one, altough it wasn't perfect

# %%
X_test = np.array([ i for i, j in test_dogs ])
y_test  = np.array([ j for i, j in test_dogs ])
model.evaluate(X_test,y_test)
# Out:
# 14/14 [==============================] - 1s 38ms/step - loss: 2.4981 - accuracy: 0.3317
# [2.4981231689453125, 0.3317422568798065]

# %%
test_images_path = './test_images'

data_dir = pathlib.Path('./train_breeds0/dog/Terrier/20ba919c6-2.jpg')
src= cv2.imread('./train_breeds0/dog/Terrier/20ba919c6-2.jpg')

img_height = 100
img_width = 100

img = tf.keras.utils.load_img(
    data_dir, target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

plt.imshow(src)
print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(labels[np.argmax(score)], 100 * np.max(score))
)
# Out:
# This image most likely belongs to LabradorRetriever with a 21.05 percent confidence.

# %%
test_images_path = './test_images'

data_dir = pathlib.Path('./train_breeds0/dog/MixedBreed/0c9133a83-5.jpg')
src= cv2.imread('./train_breeds0/dog/MixedBreed/0c9133a83-5.jpg')

img_height = 100
img_width = 100

img = tf.keras.utils.load_img(
    data_dir, target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

plt.imshow(src)
print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(labels[np.argmax(score)], 100 * np.max(score))
)
# Out:
# This image most likely belongs to MixedBreed with a 20.04 percent confidence.

# %% [markdown]
# This dog was detected correctly by the model with a confidence of 20.04%

# %% [markdown]
# As we can see, the training did not go to well, and that is mostly due to certain breeds having significantly more images than others.
# So, for improving our accuracy, we will reduce our dataset to the four breeds that have the most images.

# %% [markdown]
# Next we performed the same process on our cats photos.

# %%
cat_data_dir = pathlib.Path('./train_breeds/cats')

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  cat_data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 18990 files belonging to 57 classes.
# Using 15192 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  cat_data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 18990 files belonging to 57 classes.
# Using 3798 files for validation.

# %%
normalization_layer = layers.Rescaling(1./255)

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixel values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.045969523 0.6603486

# %%
class_names = train_ds.class_names
num_classes = len(class_names)

model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
class_names[:10:]
# Out:
# ['Abyssinian',
#  'AmericanCurl',
#  'AmericanShorthair',
#  'AmericanWirehair',
#  'AppleheadSiamese',
#  'Balinese',
#  'Bengal',
#  'Birman',
#  'Bobtail',
#  'Bombay']

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
epochs=10
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 475/475 [==============================] - 321s 673ms/step - loss: 1.8346 - accuracy: 0.5375 - val_loss: 1.7671 - val_accuracy: 0.5424
# Epoch 2/10
# 475/475 [==============================] - 351s 737ms/step - loss: 1.7784 - accuracy: 0.5421 - val_loss: 1.7729 - val_accuracy: 0.5419
# Epoch 3/10
# 475/475 [==============================] - 347s 730ms/step - loss: 1.7285 - accuracy: 0.5410 - val_loss: 1.7923 - val_accuracy: 0.5390
# Epoch 4/10
# 475/475 [==============================] - 350s 736ms/step - loss: 1.5824 - accuracy: 0.5518 - val_loss: 1.9127 - val_accuracy: 0.5187
# Epoch 5/10
# 475/475 [==============================] - 352s 741ms/step - loss: 1.2826 - accuracy: 0.6027 - val_loss: 2.3884 - val_accuracy: 0.4779
# Epoch 6/10
# 475/475 [==============================] - 350s 737ms/step - loss: 0.8687 - accuracy: 0.7112 - val_loss: 3.4950 - val_accuracy: 0.4523
# Epoch 7/10
# 475/475 [==============================] - 349s 735ms/step - loss: 0.5416 - accuracy: 0.8098 - val_loss: 4.4326 - val_accuracy: 0.4136
# Epoch 8/10
# 475/475 [==============================] - 363s 765ms/step - loss: 0.3418 - accuracy: 0.8815 - val_loss: 5.7713 - val_accuracy: 0.4315
# Epoch 9/10
# 475/475 [==============================] - 355s 748ms/step - loss: 0.2348 - accuracy: 0.9219 - val_loss: 6.1220 - val_accuracy: 0.4126
# Epoch 10/10
# 475/475 [==============================] - 355s 746ms/step - loss: 0.1764 - accuracy: 0.9450 - val_loss: 6.8833 - val_accuracy: 0.4521

# %% [markdown]
# After creating we decided to plot the values

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# Looking at them we could see that there is overfitting altough we took in consideration to use dropout layers and to augment our data

# %%
src = cv2.imread('train_breeds/cats/Bobtail/3d939327d-2.jpg')
plt.imshow(src)

# %%
test_images_path = './test_images'

data_dir = pathlib.Path('train_breeds/cats/Bobtail/3d939327d-2.jpg')
display_image = PIL.Image.open(str(data_dir))
display_image.show()

img = tf.keras.utils.load_img(
    data_dir, target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# (viewnior:37688): Gtk-WARNING **: 19:33:05.639: Unable to locate theme engine in module_path: "murrine",
#
# (viewnior:37688): Gtk-WARNING **: 19:33:05.639: Unable to locate theme engine in module_path: "murrine",
#
# (viewnior:37688): Gtk-WARNING **: 19:33:05.639: Unable to locate theme engine in module_path: "murrine",
#
# (viewnior:37688): Gtk-WARNING **: 19:33:05.642: Unable to locate theme engine in module_path: "murrine",
#
# (viewnior:37688): Gtk-WARNING **: 19:33:05.642: Unable to locate theme engine in module_path: "murrine",
#
# (viewnior:37688): Gtk-WARNING **: 19:33:05.642: Unable to locate theme engine in module_path: "murrine",
#
# (viewnior:37688): Gtk-WARNING **: 19:33:05.642: Unable to locate theme engine in module_path: "murrine",
# 1/1 [==============================] - 1s 1s/step
# This image most likely belongs to DomesticShortHair with a 94.20 percent confidence.

# %% [markdown]
# The model predicted the Bobtail cat with a 94.20 confidence that is was a Domestic Short Hair. Altough, even for us it was hard to tell the difference between them. But it is clear that we don't like this overfitting so we decided to procedd the same and perform another model on a smaller scale of data.

# %%
labels = os.listdir('./train_breeds0/cats')
print('Labels:', labels)
# Out:
# Labels: ['DomesticLongHair', 'DomesticMediumHair', 'DomesticShortHair', 'Persian', 'Siamese', 'Tabby']

# %%
train_cats =[]
for i in range(5):
    img_names=os.listdir('./train_breeds0/cats/'+labels[i]+'/')
    for img in img_names:
          src= cv2.imread('./train_breeds0/cats/'+labels[i]+'/'+img)
          src= cv2.resize(src ,(100,100),interpolation=cv2.INTER_AREA)
          train_cats.append((src,i))

# %%
random.shuffle(train_cats)

# %%
test_len = len(train_cats)*0.2

test_cats = []
for i in range(int(test_len)):
    test_cats.append(train_cats[i])
    train_cats.pop(i)

# %%
data_augmentation = keras.Sequential(
  [
   layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(0.2),
  layers.RandomContrast(0.2)
  ]
)

# %%
def prepare(ds):
  
  ds1 = map(lambda x: (data_augmentation(x[0], training=True), x[1]), ds)

  return list(ds1)

ds = prepare(train_cats)
trainCats=train_cats + ds

# %%
img_height = 100
img_width = 100
batch_size = 32

xc_train = np.array([ i for i, j in trainCats ])
yc_train  = np.array([ j for i, j in trainCats ])

model = Sequential([
  layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(10, activation='softmax'),
  
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
from keras import layers, models, callbacks

# %%
early_stop=callbacks.EarlyStopping(min_delta=0.01, patience=20, restore_best_weights=True)
history = model.fit(xc_train, yc_train, 
    validation_split=0.2,
    epochs=10,
    callbacks=[early_stop])
# Out:
# Epoch 1/10
# 59/59 [==============================] - 5s 85ms/step - loss: 1.5598 - accuracy: 0.4227 - val_loss: 1.5253 - val_accuracy: 0.4464
# Epoch 2/10
# 59/59 [==============================] - 5s 82ms/step - loss: 1.4554 - accuracy: 0.4382 - val_loss: 1.4356 - val_accuracy: 0.4528
# Epoch 3/10
# 59/59 [==============================] - 5s 90ms/step - loss: 1.4040 - accuracy: 0.4409 - val_loss: 1.4442 - val_accuracy: 0.4506
# Epoch 4/10
# 59/59 [==============================] - 5s 89ms/step - loss: 1.3419 - accuracy: 0.4597 - val_loss: 1.4493 - val_accuracy: 0.4528
# Epoch 5/10
# 59/59 [==============================] - 5s 85ms/step - loss: 1.2567 - accuracy: 0.4957 - val_loss: 1.4593 - val_accuracy: 0.4506
# Epoch 6/10
# 59/59 [==============================] - 5s 91ms/step - loss: 1.1475 - accuracy: 0.5478 - val_loss: 1.5069 - val_accuracy: 0.4378
# Epoch 7/10
# 59/59 [==============================] - 5s 90ms/step - loss: 1.0442 - accuracy: 0.6010 - val_loss: 1.6345 - val_accuracy: 0.3734
# Epoch 8/10
# 59/59 [==============================] - 5s 90ms/step - loss: 0.8885 - accuracy: 0.6643 - val_loss: 1.7234 - val_accuracy: 0.4142
# Epoch 9/10
# 59/59 [==============================] - 5s 91ms/step - loss: 0.7605 - accuracy: 0.7159 - val_loss: 1.8817 - val_accuracy: 0.4227
# Epoch 10/10
# 59/59 [==============================] - 5s 88ms/step - loss: 0.6324 - accuracy: 0.7669 - val_loss: 2.0888 - val_accuracy: 0.3712

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(10)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
X_test = np.array([ i for i, j in test_cats ])
y_test  = np.array([ j for i, j in test_cats ])
model.evaluate(X_test,y_test)
# Out:
# 10/10 [==============================] - 0s 17ms/step - loss: 1.8805 - accuracy: 0.4103
# [1.8805409669876099, 0.41034483909606934]

# %%
test_images_path = './test_images'

data_dir = pathlib.Path('./train_breeds0/cats/Siamese/4d40cfa55-1.jpg')
src= cv2.imread('./train_breeds0/cats/Siamese/4d40cfa55-1.jpg')

img_height = 100
img_width = 100

img = tf.keras.utils.load_img(
    data_dir, target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

plt.imshow(src)
print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(labels[np.argmax(score)], 100 * np.max(score))
)
# Out:
# This image most likely belongs to Siamese with a 13.49 percent confidence.

# %% [markdown]
# The predicted corectly the cat, altought with only a 13.49% confidence

# %%
test_images_path = './test_images'

data_dir = pathlib.Path('./train_breeds0/cats/Persian/3cafd9500-4.jpg')
src= cv2.imread('./train_breeds0/cats/Persian/3cafd9500-4.jpg')

img_height = 100
img_width = 100

img = tf.keras.utils.load_img(
    data_dir, target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

plt.imshow(src)
print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(labels[np.argmax(score)], 100 * np.max(score))
)
# Out:
# This image most likely belongs to Persian with a 14.39 percent confidence.

# %% [markdown]
# The model seemed to predict corectly the cat, altought with only a 14.49% confidence

# %% [markdown]
# The next approach was to try out with ResNet50 a pre-trained model found online and used by other related works.
# Other people approached this problem using Resnet50. Not even there was the prediction correct. In the related work they have used
# other dataset that contained photos with a higher quality and easy to find features. Our model was with photos of animals frpm shelter
# or that would be given our for adoption

# %%
resModel = ResNet50(weights='imagenet')
def evaluate(img_fname):
    img = image.load_img(img_fname, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    preds=resModel.predict(img_array)
    print('Predicted:', decode_predictions(preds, top=5)[0])
    plt.imshow(img)

# %%
evaluate('./train_breeds/dogs/Husky/0ff7245bd-4.jpg')
# Out:
# 1/1 [==============================] - 0s 71ms/step
# Predicted: [('n02110185', 'Siberian_husky', 0.88059324), ('n02109961', 'Eskimo_dog', 0.10518149), ('n02110063', 'malamute', 0.012427489), ('n02090622', 'borzoi', 0.00097209), ('n03218198', 'dogsled', 0.0001837694)]

# %%
evaluate('./train_breeds/dogs/Beagle/3d8a35224-6.jpg')
# Out:
# 1/1 [==============================] - 0s 65ms/step
# Predicted: [('n02088238', 'basset', 0.7604932), ('n02100735', 'English_setter', 0.13309759), ('n02088632', 'bluetick', 0.02229268), ('n02092339', 'Weimaraner', 0.013456269), ('n02110341', 'dalmatian', 0.01004415)]

# %%
evaluate('./train_breeds/dogs/Beagle/f663a91e8-8.jpg')
# Out:
# 1/1 [==============================] - 0s 66ms/step
# Predicted: [('n02108089', 'boxer', 0.178962), ('n02096585', 'Boston_bull', 0.16606681), ('n02108915', 'French_bulldog', 0.12815197), ('n02088364', 'beagle', 0.09412934), ('n02093428', 'American_Staffordshire_terrier', 0.058565307)]

# %%
evaluate('./train_breeds/dogs/WhiteGermanShepherd/58132cc85-1.jpg')
# Out:
# 1/1 [==============================] - 0s 65ms/step
# Predicted: [('n02111889', 'Samoyed', 0.455462), ('n02111500', 'Great_Pyrenees', 0.15315324), ('n02104029', 'kuvasz', 0.12945914), ('n02114548', 'white_wolf', 0.11045762), ('n02120079', 'Arctic_fox', 0.022408321)]

# %% [markdown]
# # Conclusion

# %% [markdown]
# In conclusion the dog vs cat predictor was a good one. While the dog breed or cat breed predictor was a little harder to implement on our data set, taking in account the inequality of content for each breed and the photos that were unclear or had other obstacles. The first model for dog breed performed better than on cat breeds because the dogs were found in a larger number in the train.csv than cats. The other model with the divison of the most numerous memebers of the clan cats performed better than the one on dogs, altought overfitting was noticed that we tried to correct as mush as we could.

# %% [markdown]
# It was a challenge to tried modelling our problem on this data set, but it was a good  exercise for reasearch and trial and error.
